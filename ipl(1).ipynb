# %%
data=pd.read_csv("C:/Users/Administrator/Downloads/IPL Matches 2008-2020.csv")
data.head(5)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
import pandas as pd

# %%
data.tail()
# Out:
#           id       city        date player_of_match  \
# 811  1216547      Dubai  2020-09-28  AB de Villiers
# 812  1237177      Dubai  2020-11-05       JJ Bumrah
# 813  1237178  Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181      Dubai  2020-11-10        TA Boult
#
#                                    venue  neutral_venue  \
# 811  Dubai International Cricket Stadium              0
# 812  Dubai International Cricket Stadium              0
# 813                 Sheikh Zayed Stadium              0
# 814                 Sheikh Zayed Stadium              0
# 815  Dubai International Cricket Stadium              0
#
#                            team1                team2          toss_winner  \
# 811  Royal Challengers Bangalore       Mumbai Indians       Mumbai Indians
# 812               Mumbai Indians       Delhi Capitals       Delhi Capitals
# 813  Royal Challengers Bangalore  Sunrisers Hyderabad  Sunrisers Hyderabad
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
data.shape
# Out:
# (816, 17)

# %%
data.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
data.player_of_match
# Out:
# 0         BB McCullum
# 1          MEK Hussey
# 2         MF Maharoof
# 3          MV Boucher
# 4           DJ Hussey
#             ...
# 811    AB de Villiers
# 812         JJ Bumrah
# 813     KS Williamson
# 814        MP Stoinis
# 815          TA Boult
# Name: player_of_match, Length: 816, dtype: object

# %%
data.player_of_match.unique()
# Out:
# array(['BB McCullum', 'MEK Hussey', 'MF Maharoof', 'MV Boucher',
#        'DJ Hussey', 'SR Watson', 'V Sehwag', 'ML Hayden', 'YK Pathan',
#        'KC Sangakkara', 'JDP Oram', 'AC Gilchrist', 'SM Katich',
#        'MS Dhoni', 'ST Jayasuriya', 'GD McGrath', 'SE Marsh',
#        'SA Asnodkar', 'R Vinay Kumar', 'IK Pathan', 'SM Pollock',
#        'Sohail Tanvir', 'S Sreesanth', 'A Nehra', 'SC Ganguly',
#        'CRD Fernando', 'L Balaji', 'Shoaib Akhtar', 'A Mishra',
#        'DPMD Jayawardene', 'GC Smith', 'DJ Bravo', 'M Ntini',
#        'SP Goswami', 'A Kumble', 'KD Karthik', 'JA Morkel', 'P Kumar',
#        'Umar Gul', 'SK Raina', 'SR Tendulkar', 'R Dravid', 'DL Vettori',
#        'RP Singh', 'M Muralitharan', 'CH Gayle', 'AB de Villiers',
#        'RS Bopara', 'PP Ojha', 'TM Dilshan', 'HH Gibbs', 'DP Nannes',
#        'JP Duminy', 'Yuvraj Singh', 'SB Jakati', 'JH Kallis', 'G Gambhir',
#        'RG Sharma', 'A Singh', 'S Badrinath', 'DR Smith', 'LRPL Taylor',
# ...

# %%
a=data['date'][data['player_of_match']=='A Nortje']

# %%
a.count()
# Out:
# np.int64(2)

# %%
q=data['player_of_match'].value_counts().head(20)
print(q)
# Out:
# player_of_match
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# SK Raina          14
# V Kohli           13
# G Gambhir         13
# MEK Hussey        12
# AM Rahane         12
# KA Pollard        11
# V Sehwag          11
# A Mishra          11
# AD Russell        11
# DR Smith          11
# JH Kallis         10
# AT Rayudu         10
# SE Marsh           9
# Name: count, dtype: int64

# %%
data['id']=data['id'].astype('float')

# %%
print(data)
# Out:
#             id        city        date player_of_match  \
# 0     335982.0   Bangalore  2008-04-18     BB McCullum
# 1     335983.0  Chandigarh  2008-04-19      MEK Hussey
# 2     335984.0       Delhi  2008-04-19     MF Maharoof
# 3     335985.0      Mumbai  2008-04-20      MV Boucher
# 4     335986.0     Kolkata  2008-04-20       DJ Hussey
# ..         ...         ...         ...             ...
# 811  1216547.0       Dubai  2020-09-28  AB de Villiers
# 812  1237177.0       Dubai  2020-11-05       JJ Bumrah
# 813  1237178.0   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180.0   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181.0       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# ...

# %%
data.dtypes
# Out:
# id                 float64
# city                object
# date                object
# player_of_match     object
# venue               object
# neutral_venue        int64
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# result_margin      float64
# eliminator          object
# method              object
# umpire1             object
# umpire2             object
# dtype: object

# %%
data['method']=data['method'].fillna('Dubai')
print(data)
# Out:
#             id        city        date player_of_match  \
# 0     335982.0   Bangalore  2008-04-18     BB McCullum
# 1     335983.0  Chandigarh  2008-04-19      MEK Hussey
# 2     335984.0       Delhi  2008-04-19     MF Maharoof
# 3     335985.0      Mumbai  2008-04-20      MV Boucher
# 4     335986.0     Kolkata  2008-04-20       DJ Hussey
# ..         ...         ...         ...             ...
# 811  1216547.0       Dubai  2020-09-28  AB de Villiers
# 812  1237177.0       Dubai  2020-11-05       JJ Bumrah
# 813  1237178.0   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180.0   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181.0       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# ...

# %%
data['team1'][data['venue']=='M Chinnaswamy Stadium']
# Out:
# 0      Royal Challengers Bangalore
# 10     Royal Challengers Bangalore
# 14     Royal Challengers Bangalore
# 24     Royal Challengers Bangalore
# 30     Royal Challengers Bangalore
#                   ...
# 606    Royal Challengers Bangalore
# 618    Royal Challengers Bangalore
# 621    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634                 Mumbai Indians
# Name: team1, Length: 65, dtype: object

# %%
s=data[(data['venue']=='M Chinnaswamy Stadium') & (data['winner']=='Royal Challengers Bangalore')]
print(s)
# Out:
#            id       city        date player_of_match                  venue  \
# 51   336034.0  Bangalore  2008-05-03         P Kumar  M Chinnaswamy Stadium
# 121  419112.0  Bangalore  2010-03-16       JH Kallis  M Chinnaswamy Stadium
# 124  419115.0  Bangalore  2010-03-18       JH Kallis  M Chinnaswamy Stadium
# 132  419123.0  Bangalore  2010-03-23      RV Uthappa  M Chinnaswamy Stadium
# 157  419148.0  Bangalore  2010-04-10   R Vinay Kumar  M Chinnaswamy Stadium
# 208  501232.0  Bangalore  2011-04-29         V Kohli  M Chinnaswamy Stadium
# 220  501244.0  Bangalore  2011-05-06        CH Gayle  M Chinnaswamy Stadium
# 223  501247.0  Bangalore  2011-05-08        CH Gayle  M Chinnaswamy Stadium
# 231  501255.0  Bangalore  2011-05-14        CH Gayle  M Chinnaswamy Stadium
# 242  501266.0  Bangalore  2011-05-22        CH Gayle  M Chinnaswamy Stadium
# 252  548310.0  Bangalore  2012-04-07  AB de Villiers  M Chinnaswamy Stadium
# ...

# %%
s
# Out:
#            id       city        date player_of_match                  venue  \
# 51   336034.0  Bangalore  2008-05-03         P Kumar  M Chinnaswamy Stadium
# 121  419112.0  Bangalore  2010-03-16       JH Kallis  M Chinnaswamy Stadium
# 124  419115.0  Bangalore  2010-03-18       JH Kallis  M Chinnaswamy Stadium
# 132  419123.0  Bangalore  2010-03-23      RV Uthappa  M Chinnaswamy Stadium
# 157  419148.0  Bangalore  2010-04-10   R Vinay Kumar  M Chinnaswamy Stadium
# 208  501232.0  Bangalore  2011-04-29         V Kohli  M Chinnaswamy Stadium
# 220  501244.0  Bangalore  2011-05-06        CH Gayle  M Chinnaswamy Stadium
# 223  501247.0  Bangalore  2011-05-08        CH Gayle  M Chinnaswamy Stadium
# 231  501255.0  Bangalore  2011-05-14        CH Gayle  M Chinnaswamy Stadium
# 242  501266.0  Bangalore  2011-05-22        CH Gayle  M Chinnaswamy Stadium
# 252  548310.0  Bangalore  2012-04-07  AB de Villiers  M Chinnaswamy Stadium
# ...

# %%
s.count()
# Out:
# id                 29
# city               29
# date               29
# player_of_match    29
# venue              29
# neutral_venue      29
# team1              29
# team2              29
# toss_winner        29
# toss_decision      29
# winner             29
# result             29
# result_margin      28
# eliminator         29
# method             29
# umpire1            29
# umpire2            29
# dtype: int64

# %%
z=data['venue'].unique()

# %%
print(z)
# Out:
# ['M Chinnaswamy Stadium' 'Punjab Cricket Association Stadium, Mohali'
#  'Feroz Shah Kotla' 'Wankhede Stadium' 'Eden Gardens'
#  'Sawai Mansingh Stadium' 'Rajiv Gandhi International Stadium, Uppal'
#  'MA Chidambaram Stadium, Chepauk' 'Dr DY Patil Sports Academy' 'Newlands'
#  "St George's Park" 'Kingsmead' 'SuperSport Park' 'Buffalo Park'
#  'New Wanderers Stadium' 'De Beers Diamond Oval' 'OUTsurance Oval'
#  'Brabourne Stadium' 'Sardar Patel Stadium, Motera' 'Barabati Stadium'
#  'Vidarbha Cricket Association Stadium, Jamtha'
#  'Himachal Pradesh Cricket Association Stadium' 'Nehru Stadium'
#  'Holkar Cricket Stadium'
#  'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium'
#  'Subrata Roy Sahara Stadium'
#  'Shaheed Veer Narayan Singh International Stadium'
#  'JSCA International Stadium Complex' 'Sheikh Zayed Stadium'
#  'Sharjah Cricket Stadium' 'Dubai International Cricket Stadium'
#  'Maharashtra Cricket Association Stadium'
# ...

# %%
len(z)
# Out:
# 36

# %%
data
# Out:
#             id        city        date player_of_match  \
# 0     335982.0   Bangalore  2008-04-18     BB McCullum
# 1     335983.0  Chandigarh  2008-04-19      MEK Hussey
# 2     335984.0       Delhi  2008-04-19     MF Maharoof
# 3     335985.0      Mumbai  2008-04-20      MV Boucher
# 4     335986.0     Kolkata  2008-04-20       DJ Hussey
# ..         ...         ...         ...             ...
# 811  1216547.0       Dubai  2020-09-28  AB de Villiers
# 812  1237177.0       Dubai  2020-11-05       JJ Bumrah
# 813  1237178.0   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180.0   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181.0       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# ...

# %%
data.toss_decision.unique()
# Out:
# array(['field', 'bat'], dtype=object)

# %%
q=data[(data['toss_decision']=='field') & (data['toss_decision']!='bat')]

# %%
print(q)
# Out:
#             id        city        date player_of_match  \
# 0     335982.0   Bangalore  2008-04-18     BB McCullum
# 7     335989.0     Chennai  2008-04-23       ML Hayden
# 8     335990.0   Hyderabad  2008-04-24       YK Pathan
# 9     335991.0  Chandigarh  2008-04-25   KC Sangakkara
# 10    335992.0   Bangalore  2008-04-26       SR Watson
# ..         ...         ...         ...             ...
# 801  1216537.0   Abu Dhabi  2020-10-30       BA Stokes
# 803  1216539.0       Dubai  2020-09-25         PP Shaw
# 811  1216547.0       Dubai  2020-09-28  AB de Villiers
# 812  1237177.0       Dubai  2020-11-05       JJ Bumrah
# 813  1237178.0   Abu Dhabi  2020-11-06   KS Williamson
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 7               MA Chidambaram Stadium, Chepauk              0
# 8     Rajiv Gandhi International Stadium, Uppal              0
# ...

# %%
data.toss_decision.describe()
# Out:
# count       816
# unique        2
# top       field
# freq        496
# Name: toss_decision, dtype: object

# %%
q.count()
# Out:
# id                 496
# city               488
# date               496
# player_of_match    493
# venue              496
# neutral_venue      496
# team1              496
# team2              496
# toss_winner        496
# toss_decision      496
# winner             493
# result             493
# result_margin      485
# eliminator         493
# method             496
# umpire1            496
# umpire2            496
# dtype: int64

# %%
q=data[(data['toss_decision']!='field') & (data['toss_decision']=='bat')]

# %%
q.count()
# Out:
# id                 320
# city               315
# date               320
# player_of_match    319
# venue              320
# neutral_venue      320
# team1              320
# team2              320
# toss_winner        320
# toss_decision      320
# winner             319
# result             319
# result_margin      314
# eliminator         319
# method             320
# umpire1            320
# umpire2            320
# dtype: int64

# %%
data.result.unique()
# Out:
# array(['runs', 'wickets', 'tie', nan], dtype=object)

# %%
q=data[(data['result']=='runs') & (data['result']!='wickets')]

# %%
q.count()
# Out:
# id                 364
# city               359
# date               364
# player_of_match    364
# venue              364
# neutral_venue      364
# team1              364
# team2              364
# toss_winner        364
# toss_decision      364
# winner             364
# result             364
# result_margin      364
# eliminator         364
# method             364
# umpire1            364
# umpire2            364
# dtype: int64

# %%
w=data[(data['result']=='wickets') & (data['result']!='runs')]

# %%
w.count()
# Out:
# id                 435
# city               427
# date               435
# player_of_match    435
# venue              435
# neutral_venue      435
# team1              435
# team2              435
# toss_winner        435
# toss_decision      435
# winner             435
# result             435
# result_margin      435
# eliminator         435
# method             435
# umpire1            435
# umpire2            435
# dtype: int64

# %%
w=data[(data['result']=='wickets') & (data['result']!='tie')]
w.count()
# Out:
# id                 435
# city               427
# date               435
# player_of_match    435
# venue              435
# neutral_venue      435
# team1              435
# team2              435
# toss_winner        435
# toss_decision      435
# winner             435
# result             435
# result_margin      435
# eliminator         435
# method             435
# umpire1            435
# umpire2            435
# dtype: int64

# %%
w=data[(data['result']!='wickets') & (data['result']=='tie')]
w.count()
# Out:
# id                 13
# city               13
# date               13
# player_of_match    13
# venue              13
# neutral_venue      13
# team1              13
# team2              13
# toss_winner        13
# toss_decision      13
# winner             13
# result             13
# result_margin       0
# eliminator         13
# method             13
# umpire1            13
# umpire2            13
# dtype: int64

# %%
data
# Out:
#             id        city        date player_of_match  \
# 0     335982.0   Bangalore  2008-04-18     BB McCullum
# 1     335983.0  Chandigarh  2008-04-19      MEK Hussey
# 2     335984.0       Delhi  2008-04-19     MF Maharoof
# 3     335985.0      Mumbai  2008-04-20      MV Boucher
# 4     335986.0     Kolkata  2008-04-20       DJ Hussey
# ..         ...         ...         ...             ...
# 811  1216547.0       Dubai  2020-09-28  AB de Villiers
# 812  1237177.0       Dubai  2020-11-05       JJ Bumrah
# 813  1237178.0   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180.0   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181.0       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# ...

# %%
q=data[['id', 'team1', 'team2', 'winner']]

# %%
print(q)
# Out:
#             id                        team1                        team2  \
# 0     335982.0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1     335983.0              Kings XI Punjab          Chennai Super Kings
# 2     335984.0             Delhi Daredevils             Rajasthan Royals
# 3     335985.0               Mumbai Indians  Royal Challengers Bangalore
# 4     335986.0        Kolkata Knight Riders              Deccan Chargers
# ..         ...                          ...                          ...
# 811  1216547.0  Royal Challengers Bangalore               Mumbai Indians
# 812  1237177.0               Mumbai Indians               Delhi Capitals
# 813  1237178.0  Royal Challengers Bangalore          Sunrisers Hyderabad
# 814  1237180.0               Delhi Capitals          Sunrisers Hyderabad
# 815  1237181.0               Delhi Capitals               Mumbai Indians
#
#                           winner
# 0          Kolkata Knight Riders
# ...
